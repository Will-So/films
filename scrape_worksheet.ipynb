# %% [markdown]
# # Data From the MovieMojo

# %% [markdown]
# Data | Why
# -- | --
# Release Date | The month is likely important
# Total Lifetime Gross Domestic and Foreign |
# Domestic Weekend |
# ^^ Percent of total gross |may be evident of cult classic thing or something. Interesting to compare against remakes and everything else
# Genre | interesting metadata
# Runtime | metadata
# MPAA rating | Shown to be important
# Produciton Budget | shown to be important ; main thing.
# Actors |
# Producers |
# Directors|

# %% [markdown]
# # Getting the Movie Lists

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'http://www.boxofficemojo.com/movies/alphabetical.htm?letter=NUM&p=.htm'
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text)

# %%
soup
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html lang="en">
# <head>
# <meta content="text/html;charset=utf-8" http-equiv="Content-type"/>
# <title>Alphabetical Movie Index, A-Z</title>
# <meta content="movie, index, alphabetical, box, office, data, film, weekend, result, a-z" name="keywords"/>
# <meta content="Alphabetical movie index with box office results." name="description"/>
# <link charset="utf-8" href="/css/mojo.css?1" media="screen" rel="stylesheet" title="no title" type="text/css"/>
# <link charset="utf-8" href="/css/mojo.css?1" media="print" rel="stylesheet" title="no title" type="text/css"/> <style type="text/css">
#         .alpha-nav-holder {
#             text-align: center;
#             width: 100%;
#         }
#     </style>
# </head>
# <body>
# <iframe frameborder="0" height="1" id="sis_pixel_sitewide" marginheight="0" marginwidth="0" style="display: none;" width="1"></iframe>
# <script>
# ...

# %%
//*[@id="body"]/div/table/tbody/tr/td/table/tbody/tr[2]/td/table[2]

# %%
import string
letter_urls = ['http://www.boxofficemojo.com/movies/alphabetical.htm?letter=' + i for
                   i in string.ascii_lowercase]
letter_urls.append('http://www.boxofficemojo.com/movies/alphabetical.htm?letter=NUM')

# %%
len(letter_urls)
# Out:
# 27

# %%
letter_urls
# Out:
# ['http://www.boxofficemojo.com/movies/alphabetical.htm?letter=a',
#  'http://www.boxofficemojo.com/movies/alphabetical.htm?letter=b',
#  'http://www.boxofficemojo.com/movies/alphabetical.htm?letter=c',
#  'http://www.boxofficemojo.com/movies/alphabetical.htm?letter=d',
#  'http://www.boxofficemojo.com/movies/alphabetical.htm?letter=e',
#  'http://www.boxofficemojo.com/movies/alphabetical.htm?letter=f',
#  'http://www.boxofficemojo.com/movies/alphabetical.htm?letter=g',
#  'http://www.boxofficemojo.com/movies/alphabetical.htm?letter=h',
#  'http://www.boxofficemojo.com/movies/alphabetical.htm?letter=i',
#  'http://www.boxofficemojo.com/movies/alphabetical.htm?letter=j',
#  'http://www.boxofficemojo.com/movies/alphabetical.htm?letter=k',
#  'http://www.boxofficemojo.com/movies/alphabetical.htm?letter=l',
#  'http://www.boxofficemojo.com/movies/alphabetical.htm?letter=m',
#  'http://www.boxofficemojo.com/movies/alphabetical.htm?letter=n',
# ...

# %% [markdown]
# # The Functions

# %%
def iterate_letters():
    """

    :param letter:
    :return: List of the URLs for each letter
    """

    letter_urls = ['http://www.boxofficemojo.com/movies/alphabetical.htm?letter=' + i for
                   i in string.ascii_lowercase]

    letter_urls.append('http://www.boxofficemojo.com/movies/alphabetical.htm?letter=NUM')

    assert len(letter_urls) == 27

    return letter_urls

# %%
letter_urls = iterate_letters()

# %%
letter_urls
# Out:
# ['http://www.boxofficemojo.com/movies/alphabetical.htm?letter=a',
#  'http://www.boxofficemojo.com/movies/alphabetical.htm?letter=b',
#  'http://www.boxofficemojo.com/movies/alphabetical.htm?letter=c',
#  'http://www.boxofficemojo.com/movies/alphabetical.htm?letter=d',
#  'http://www.boxofficemojo.com/movies/alphabetical.htm?letter=e',
#  'http://www.boxofficemojo.com/movies/alphabetical.htm?letter=f',
#  'http://www.boxofficemojo.com/movies/alphabetical.htm?letter=g',
#  'http://www.boxofficemojo.com/movies/alphabetical.htm?letter=h',
#  'http://www.boxofficemojo.com/movies/alphabetical.htm?letter=i',
#  'http://www.boxofficemojo.com/movies/alphabetical.htm?letter=j',
#  'http://www.boxofficemojo.com/movies/alphabetical.htm?letter=k',
#  'http://www.boxofficemojo.com/movies/alphabetical.htm?letter=l',
#  'http://www.boxofficemojo.com/movies/alphabetical.htm?letter=m',
#  'http://www.boxofficemojo.com/movies/alphabetical.htm?letter=n',
# ...

# %% [markdown]
# # Getting the Movie Data

# %%
soup
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html lang="en">
# <head>
# <meta content="text/html;charset=utf-8" http-equiv="Content-type"/>
# <title>Alphabetical Movie Index, A-Z</title>
# <meta content="movie, index, alphabetical, box, office, data, film, weekend, result, a-z" name="keywords"/>
# <meta content="Alphabetical movie index with box office results." name="description"/>
# <link charset="utf-8" href="/css/mojo.css?1" media="screen" rel="stylesheet" title="no title" type="text/css"/>
# <link charset="utf-8" href="/css/mojo.css?1" media="print" rel="stylesheet" title="no title" type="text/css"/> <style type="text/css">
#         .alpha-nav-holder {
#             text-align: center;
#             width: 100%;
#         }
#     </style>
# </head>
# <body>
# <iframe frameborder="0" height="1" id="sis_pixel_sitewide" marginheight="0" marginwidth="0" style="display: none;" width="1"></iframe>
# <script>
# ...

# %%
# A has a bunch
# Q has 0; NUM

_class="alpha-nav-holder"

soup = BeautifulSoup(requests.get(letter_urls[0]).text)


# Find All As in there

# %%
soup.find("alpha-nav-holder")

# %%
s

# %%
soup
# Out:
# <html><body><p>http://www.boxofficemojo.com/movies/alphabetical.htm?letter=a</p></body></html>

# %%
def iterate_letter_category(letter_urls):
    """

    :param letter:
    :return: List of the URL of letter categories
    """
    letter_category_urls = []
    for url in letter_urls:
        letter_category_urls.append(url) # The first item is selected automatically
        text = requests.get(url).text
        soup = BeautifulSoup(text)
        soup.find_all()
        





    return letter_category_urls

test_cases = iterate_letter_category(
    ['http://www.boxofficemojo.com/movies/alphabetical.htm?letter=NUM', 
     'http://www.boxofficemojo.com/movies/alphabetical.htm?letter=a'])
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html lang="en">
#  <head>
#   <meta content="text/html;charset=utf-8" http-equiv="Content-type"/>
#   <title>
#    Alphabetical Movie Index, A-Z
#   </title>
#   <meta content="movie, index, alphabetical, box, office, data, film, weekend, result, a-z" name="keywords"/>
#   <meta content="Alphabetical movie index with box office results." name="description"/>
#   <link charset="utf-8" href="/css/mojo.css?1" media="screen" rel="stylesheet" title="no title" type="text/css"/>
#   <link charset="utf-8" href="/css/mojo.css?1" media="print" rel="stylesheet" title="no title" type="text/css"/>
#   <style type="text/css">
#    .alpha-nav-holder {
#             text-align: center;
#             width: 100%;
#         }
#   </style>
#  </head>
#  <body>
#   <iframe frameborder="0" height="1" id="sis_pixel_sitewide" marginheight="0" marginwidth="0" style="display: none;" width="1">
# ...

# %%
type(test_cases)
# Out:
# list

# %%
type(test_cases[0])
# Out:
# str

# %%
import pandas as pd
sequels = pd.read_csv('movies_with_sequels.csv')

# %%
sequels = sequels.drop('position', 1)

# %% [markdown]
# Have
#
# - Directors
# - IMDB Ratings
# - Number or ratings
# - Run Time
# - Genres
# - URL
# - Title
#
# Want
#
# -
#
#
# Maybe
#
# - Scripts
# -

# %%
sequels
# Out:
#           const                   created                  modified  \
# 0     tt0145487  Wed Nov  2 23:54:47 2011  Wed Nov  2 23:54:47 2011
# 1     tt0316654  Wed Nov  2 23:55:12 2011  Wed Nov  2 23:55:12 2011
# 2     tt0413300  Wed Nov  2 23:55:35 2011  Wed Nov  2 23:55:35 2011
# 3     tt0133093  Wed Nov  2 23:56:13 2011  Wed Nov  2 23:56:13 2011
# 4     tt0234215  Wed Nov  2 23:56:20 2011  Wed Nov  2 23:56:20 2011
# 5     tt0242653  Wed Nov  2 23:56:27 2011  Wed Nov  2 23:56:27 2011
# 6     tt0120737  Thu Nov  3 00:05:21 2011  Thu Nov  3 00:05:21 2011
# 7     tt0167261  Thu Nov  3 00:05:31 2011  Thu Nov  3 00:05:31 2011
# 8     tt0167260  Thu Nov  3 00:05:35 2011  Thu Nov  3 00:05:35 2011
# 9     tt0088763  Thu Nov  3 00:05:57 2011  Thu Nov  3 00:05:57 2011
# 10    tt0096874  Thu Nov  3 00:06:19 2011  Thu Nov  3 00:06:19 2011
# 11    tt0099088  Thu Nov  3 00:06:31 2011  Thu Nov  3 00:06:31 2011
# 12    tt0093409  Thu Nov  3 00:06:53 2011  Thu Nov  3 00:06:53 2011
# ...

# %% [markdown]
# # Useful Repositories

# %% [markdown]
# - [This](https://github.com/AkshatM/BoxOfficeMojo-Data) does a good job of parsing the tables.
# - [This](https://github.com/arnomoonens/Box-Office-Mojo-Scraper) provides a good benchmark to scrape against
